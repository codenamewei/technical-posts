# %%
import pandas as pd

key = "winequality-red"
df = pd.read_csv(f"data/{key}_native.csv")

print(df.shape)
df.head()
# Out:
# (1599000, 12)
#    fixed acidity   volatile acidity   citric acid   residual sugar  \
# 0            7.4               0.70          0.00              1.9
# 1            7.8               0.88          0.00              2.6
# 2            7.8               0.76          0.04              2.3
# 3           11.2               0.28          0.56              1.9
# 4            7.4               0.70          0.00              1.9
#
#     chlorides   free sulfur dioxide   total sulfur dioxide   density    pH  \
# 0       0.076                  11.0                   34.0    0.9978  3.51
# 1       0.098                  25.0                   67.0    0.9968  3.20
# 2       0.092                  15.0                   54.0    0.9970  3.26
# 3       0.075                  17.0                   60.0    0.9980  3.16
# 4       0.076                  11.0                   34.0    0.9978  3.51
#
#     sulphates   alcohol   quality
# 0        0.56       9.4         5
# ...

# %%
print(df.shape)
df.head()
# Out:
# (1599000, 12)
#    fixed acidity   volatile acidity   citric acid   residual sugar  \
# 0            7.4               0.70          0.00              1.9
# 1            7.8               0.88          0.00              2.6
# 2            7.8               0.76          0.04              2.3
# 3           11.2               0.28          0.56              1.9
# 4            7.4               0.70          0.00              1.9
#
#     chlorides   free sulfur dioxide   total sulfur dioxide   density    pH  \
# 0       0.076                  11.0                   34.0    0.9978  3.51
# 1       0.098                  25.0                   67.0    0.9968  3.20
# 2       0.092                  15.0                   54.0    0.9970  3.26
# 3       0.075                  17.0                   60.0    0.9980  3.16
# 4       0.076                  11.0                   34.0    0.9978  3.51
#
#     sulphates   alcohol   quality
# 0        0.56       9.4         5
# ...
